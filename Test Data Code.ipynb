# %%
import matplotlib.pyplot as plt

# Given weights and constants
w1 = 0.38478182
w2 = 0.58343862
w3 = 0.2795628
T_Z1 = 17.6
T_Z2 = 29.28
T_Z3 = 34.28

# Generate random D_t values
np.random.seed(42)  # Setting seed for reproducibility
D_t = np.random.uniform(2, 35, 60)

# Calculate the values for each t
values = w1 * T_Z1 + w2 * T_Z2 + w3 * T_Z3 - D_t

# Plot the results
t_values = range(1, 61)

plt.plot(t_values, values,color='red', label='Liability Duration')
plt.axhline(T_Z1, color='blue', label='Bond 1')
plt.axhline(T_Z2, color='grey', label='Bond 2')
plt.axhline(T_Z3, color='green', label='Bond 3')

plt.xlabel('Time(months)')
plt.ylabel('Duration')
plt.title('Test Data')
plt.legend(loc="upper center",bbox_to_anchor=(0.5, -0.2),ncol = 3)
plt.show()
